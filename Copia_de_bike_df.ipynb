# %% [markdown]
# <a href="https://colab.research.google.com/github/joseluisech/bike_df/blob/main/Copia_de_bike_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
filename='/content/RailsToTrails_National Count Data_week.xlsx'
xl_file = pd.ExcelFile(filename)

dfs = {sheet_name: xl_file.parse(sheet_name)
      for sheet_name in xl_file.sheet_names}

bike_df = dfs['Total Count data (31 counters)']
bike_df.head()
# Out:
#   Timeframe    Week of   2019 counts (31 counters)  \
# 0    Week 1 2020-12-30                      167679
# 1    Week 2 2020-01-06                       82340
# 2    Week 3 2020-01-13                       62315
# 3    Week 4 2020-01-20                       75801
# 4    Week 5 2020-01-27                       75841
#
#     2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 0                      183546          NaN          0.094627    1.094627
# 1                       97140          NaN          0.179743  117.974253
# 2                       75782          NaN          0.216112  121.611169
# 3                       83809          NaN          0.105645  110.564504
# 4                       94738          NaN          0.249166  124.916602
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# ...

# %%
#1 Solo seleccionen los datos después del 31 de julio de 2020.

filter_date = bike_df['Week of']>'2020-07-31'
filter_date.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Week of, dtype: bool

# %%
#2 Solo seleccionen los datos donde la columna “Change 2019-2020” es superior al 100 % (superior 1).
filter_change = bike_df['Change 2019-2020']>1
filter_change.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Change 2019-2020, dtype: bool

# %%
#3 ¡Únanlos! ¿Hubo alguna semana en la segunda mitad del año (después del 31 de julio de 2020) en la que el cambio fuera superior al 100 %?
bike_df = bike_df.loc[filter_date & filter_change, :]
bike_df
# Out:
# Empty DataFrame
# Columns: [Timeframe, Week of,  2019 counts (31 counters),  2020 counts (31 counters), 2021 Counts, Change 2019-2020, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9]
# Index: []

# %% [markdown]
# No hubo ninguna semana en la segunda mitad de la semana, donde el cambio sea superior a 1.
